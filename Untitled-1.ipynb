# %%
import time
class cls_1:
    def func_1(self,number,number1):
        print(number,number1)
    varblue1 = "hello"
from_the_class = cls_1()
from_the_class.func_1("number",12)
print(from_the_class.varblue1)
list_for_loop = [
["python","html"],
["c++","javascript"],
]
for for_loop_first in list_for_loop:
    for for_loop_second in for_loop_first:
        time.sleep(0.5)
        print(for_loop_second)
# Out:
# number 12
# hello
# python
# html
# c++
# javascript

# %% [markdown]
# <'html>
